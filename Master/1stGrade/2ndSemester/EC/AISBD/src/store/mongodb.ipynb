# %%
import pandas as pd
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pyarrow.parquet as pq

# %%
url = 'mongodb+srv://henriquealvelos:yGZhgWOOJPEetlPX@cluster0.sbwbqn8.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
mongo_client = MongoClient(url, server_api=ServerApi('1'))
try:
    mongo_client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
songs = mongo_client['aisbd-songs-bi']['songs']
# clear songs
songs.delete_many({})
parquet_file = pq.ParquetFile('../../data/merged_parquet/merged4.parquet')

# %%
weeks = []
for i in range(parquet_file.num_row_groups):
    table = parquet_file.read_row_group(i)
    chunk = table.to_pandas()

    grouped = chunk.groupby('location')
    #location        week  danceability   energy  loudness speechiness       tavg       tmin       tmax      prcp       wspd
    for name, group in grouped:
        location = name
        for index, row in group.iterrows():
            week = {
                'week': row['week'],
                'location': row['location'],
                'latitude': row['latitude'],
                'longitude': row['longitude'],
                'danceability': row['danceability'],
                'energy': row['energy'],
                'loudness': row['loudness'],
                'speechiness': row['speechiness'],
                'temperature_average': row['tavg'],
                'temperature_minimum': row['tmin'],
                'temperature_maximum': row['tmax'],
                'precipitation': row['prcp'],
                'wind_speed': row['wspd'],
            }
            weeks.append(week)

songs.insert_many(weeks)
# Out:
# InsertManyResult([ObjectId('665f84613ba00e975bb6b63a'), ObjectId('665f84613ba00e975bb6b63b'), ObjectId('665f84613ba00e975bb6b63c'), ObjectId('665f84613ba00e975bb6b63d'), ObjectId('665f84613ba00e975bb6b63e'), ObjectId('665f84613ba00e975bb6b63f'), ObjectId('665f84613ba00e975bb6b640'), ObjectId('665f84613ba00e975bb6b641'), ObjectId('665f84613ba00e975bb6b642'), ObjectId('665f84613ba00e975bb6b643'), ObjectId('665f84613ba00e975bb6b644'), ObjectId('665f84613ba00e975bb6b645'), ObjectId('665f84613ba00e975bb6b646'), ObjectId('665f84613ba00e975bb6b647'), ObjectId('665f84613ba00e975bb6b648'), ObjectId('665f84613ba00e975bb6b649'), ObjectId('665f84613ba00e975bb6b64a'), ObjectId('665f84613ba00e975bb6b64b'), ObjectId('665f84613ba00e975bb6b64c'), ObjectId('665f84613ba00e975bb6b64d'), ObjectId('665f84613ba00e975bb6b64e'), ObjectId('665f84613ba00e975bb6b64f'), ObjectId('665f84613ba00e975bb6b650'), ObjectId('665f84613ba00e975bb6b651'), ObjectId('665f84613ba00e975bb6b652'), ObjectId('665f84613ba00e975bb6
# ...
