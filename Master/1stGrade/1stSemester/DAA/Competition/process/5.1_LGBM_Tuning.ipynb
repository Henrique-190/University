# %% [markdown]
# # Tuning LGBM

# %%
import utils as utils
import holidays
import re
from collections import Counter
import sklearn as skl
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn import preprocessing
from scipy.stats import zscore
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import numpy as np
import time
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.metrics import classification_report,plot_confusion_matrix, accuracy_score
from sklearn.linear_model import LinearRegression, LogisticRegression
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import boxcox, boxcox_normmax, probplot
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingRandomSearchCV
import lightgbm as lgb
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

# %% [markdown]
# # LEITURA

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df


def import_data(file):
    """create a dataframe and optimize its memory usage"""
    df = pd.read_csv(file, parse_dates=True, keep_date_col=True)
    df = reduce_mem_usage(df)
    return df

# %%
incidentes = import_data("../input/train_data_outliers_cleaned.csv")
testev= import_data("../input/test_data_outliers_cleaned.csv")
# Out:
# Memory usage of dataframe is 0.76 MB
# Memory usage after optimization is: 0.13 MB
# Decreased by 83.1%
# Memory usage of dataframe is 0.17 MB
# Memory usage after optimization is: 0.03 MB
# Decreased by 81.5%

# %%
incidentes = incidentes.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))

# %%
incidentes.head()
# Out:
#    Unnamed0  magnitude_of_delay  delay_in_seconds  luminosity  \
# 0         0                   0                 0           0
# 1         1                   0               385           0
# 2         2                   0                69           2
# 3         3                   2              2297           2
# 4         4                   0                 0           2
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  \
# 0             12.0            1013.0          70.0             1.0         0
# 1             12.0            1007.0          91.0             1.0         0
# 2             14.0            1025.0          64.0             0.0         0
# 3             15.0            1028.0          75.0             1.0         0
# 4             27.0            1020.0          52.0             1.0         0
#
#    incidents  National  Regional  day_of_month  week_day  month  hour  \
# 0          0         0         0            15         0      3    23
# 1          0         1         0            25         5     12    18
# 2          1         0         0            12         4      3    15
# 3          4        10         1            29         2      9     9
# 4          3         5         0            13         6      6    11
#
#    day_of_year  season  is_holiday  is_weekend
# 0           74       0           0           1
# 1          359       3           1           1
# 2           71       0           0           1
# 3          272       3           0           1
# 4          164       1           0           1

# %%
incidentes = incidentes.drop(['Unnamed0'], axis=1)

# %%
incidentes.head()
# Out:
#    magnitude_of_delay  delay_in_seconds  luminosity  avg_temperature  \
# 0                   0                 0           0             12.0
# 1                   0               385           0             12.0
# 2                   0                69           2             14.0
# 3                   2              2297           2             15.0
# 4                   0                 0           2             27.0
#
#    avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  incidents  \
# 0            1013.0          70.0             1.0         0          0
# 1            1007.0          91.0             1.0         0          0
# 2            1025.0          64.0             0.0         0          1
# 3            1028.0          75.0             1.0         0          4
# 4            1020.0          52.0             1.0         0          3
#
#    National  Regional  day_of_month  week_day  month  hour  day_of_year  \
# 0         0         0            15         0      3    23           74
# 1         1         0            25         5     12    18          359
# 2         0         0            12         4      3    15           71
# 3        10         1            29         2      9     9          272
# 4         5         0            13         6      6    11          164
#
#    season  is_holiday  is_weekend
# 0       0           0           1
# 1       3           1           1
# 2       0           0           1
# 3       3           0           1
# 4       1           0           1

# %%
#divisão do target
x = incidentes.drop(['incidents'], axis=1)
y = incidentes['incidents']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# This function defines a learning rate schedule that decreases the learning rate by a factor of 0.99 every time the current_iter argument increases by 1. The learning rate will never go below 1e-3 (0.001). Here's an example of how you could use this function to train a model using stochastic gradient descent with a fixed number of iterations

# %%
def learning_rate_010_decay_power_099(current_iter): #2
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_010_decay_power_0995(current_iter): #1
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.995, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_005_decay_power_099(current_iter): #3
    base_learning_rate = 0.05
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

# %% [markdown]
# ### OBSERVAR PARÂMETROS

# %%
fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc_mu', 
            "eval_set" : [(X_test,y_test)],
            #'callbacks': [lgb.reset_parameter(learning_rate=learning_rate_005_decay_power_099)],
            'verbose': 100}

# %%
param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]
             }

# %%
#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = LGBMClassifier(boosting_type='gbdt', learning_rate=0.1, n_estimators=5000, random_state=42)
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='accuracy',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

# %%
gs.fit(X_train, y_train, **fit_params)
print('Best score reached: {} with params: {} '.format(gs.best_score_, gs.best_params_))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.978072	valid_0's multi_logloss: 0.460653
# [200]	valid_0's auc_mu: 0.9823	valid_0's multi_logloss: 0.379166
# [300]	valid_0's auc_mu: 0.984063	valid_0's multi_logloss: 0.337993
# [400]	valid_0's auc_mu: 0.984762	valid_0's multi_logloss: 0.317251
# [500]	valid_0's auc_mu: 0.985227	valid_0's multi_logloss: 0.302258
# [600]	valid_0's auc_mu: 0.985692	valid_0's multi_logloss: 0.293145
# [700]	valid_0's auc_mu: 0.985985	valid_0's multi_logloss: 0.285916
# [800]	valid_0's auc_mu: 0.986471	valid_0's multi_logloss: 0.279305
# [900]	valid_0's auc_mu: 0.986829	valid_0's multi_logloss: 0.274908
# [1000]	valid_0's auc_mu: 0.987014	valid_0's multi_logloss: 0.271653
# [1100]	valid_0's auc_mu: 0.987128	valid_0's multi_logloss: 0.26856
# [1200]	valid_0's auc_mu: 0.987321	valid_0's multi_logloss: 0.264532
# Early stopping, best iteration is:
# [1184]	valid_0's auc_mu: 0.987362	valid_0's multi_logloss: 0.265158
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.975605	valid_0's multi_logloss: 0.469383
# [200]	valid_0's auc_mu: 0.980591	valid_0's multi_logloss: 0.389705
# [300]	valid_0's auc_mu: 0.982634	valid_0's multi_logloss: 0.353067
# [400]	valid_0's auc_mu: 0.983556	valid_0's multi_logloss: 0.330583
# [500]	valid_0's auc_mu: 0.9841	valid_0's multi_logloss: 0.313254
# [600]	valid_0's auc_mu: 0.984696	valid_0's multi_logloss: 0.301749
# [700]	valid_0's auc_mu: 0.98529	valid_0's multi_logloss: 0.291776
# [800]	valid_0's auc_mu: 0.985732	valid_0's multi_logloss: 0.284799
# [900]	valid_0's auc_mu: 0.985946	valid_0's multi_logloss: 0.279688
# Early stopping, best iteration is:
# [884]	valid_0's auc_mu: 0.985988	valid_0's multi_logloss: 0.280186
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.975519	valid_0's multi_logloss: 0.470999
# [200]	valid_0's auc_mu: 0.980457	valid_0's multi_logloss: 0.387869
# [300]	valid_0's auc_mu: 0.982089	valid_0's multi_logloss: 0.351269
# [400]	valid_0's auc_mu: 0.98292	valid_0's multi_logloss: 0.330746
# [500]	valid_0's auc_mu: 0.983288	valid_0's multi_logloss: 0.318182
# [600]	valid_0's auc_mu: 0.983664	valid_0's multi_logloss: 0.308565
# Early stopping, best iteration is:
# [665]	valid_0's auc_mu: 0.984075	valid_0's multi_logloss: 0.303015
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.979055	valid_0's multi_logloss: 0.459354
# [200]	valid_0's auc_mu: 0.981148	valid_0's multi_logloss: 0.408321
# [300]	valid_0's auc_mu: 0.981565	valid_0's multi_logloss: 0.387651
# [400]	valid_0's auc_mu: 0.981776	valid_0's multi_logloss: 0.377094
# [500]	valid_0's auc_mu: 0.981886	valid_0's multi_logloss: 0.372197
# Early stopping, best iteration is:
# [487]	valid_0's auc_mu: 0.98189	valid_0's multi_logloss: 0.372643
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.977634	valid_0's multi_logloss: 0.470223
# [200]	valid_0's auc_mu: 0.979995	valid_0's multi_logloss: 0.412222
# [300]	valid_0's auc_mu: 0.981132	valid_0's multi_logloss: 0.390266
# [400]	valid_0's auc_mu: 0.981324	valid_0's multi_logloss: 0.381295
# Early stopping, best iteration is:
# [411]	valid_0's auc_mu: 0.981348	valid_0's multi_logloss: 0.380566
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.977086	valid_0's multi_logloss: 0.475158
# [200]	valid_0's auc_mu: 0.979292	valid_0's multi_logloss: 0.417347
# [300]	valid_0's auc_mu: 0.980299	valid_0's multi_logloss: 0.395691
# [400]	valid_0's auc_mu: 0.980856	valid_0's multi_logloss: 0.383523
# [500]	valid_0's auc_mu: 0.981098	valid_0's multi_logloss: 0.37609
# [600]	valid_0's auc_mu: 0.981223	valid_0's multi_logloss: 0.372158
# Early stopping, best iteration is:
# [609]	valid_0's auc_mu: 0.981235	valid_0's multi_logloss: 0.371971
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58555
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58555
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [69]	valid_0's auc_mu: 0.915585	valid_0's multi_logloss: 1.07505
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.919339	valid_0's multi_logloss: 1.07183
# Early stopping, best iteration is:
# [89]	valid_0's auc_mu: 0.919398	valid_0's multi_logloss: 1.07318
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.917962	valid_0's multi_logloss: 1.06737
# Early stopping, best iteration is:
# [85]	valid_0's auc_mu: 0.918286	valid_0's multi_logloss: 1.06919
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.988019	valid_0's multi_logloss: 0.267872
# [200]	valid_0's auc_mu: 0.988953	valid_0's multi_logloss: 0.247724
# Early stopping, best iteration is:
# [244]	valid_0's auc_mu: 0.989143	valid_0's multi_logloss: 0.244475
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.986927	valid_0's multi_logloss: 0.278064
# [200]	valid_0's auc_mu: 0.987428	valid_0's multi_logloss: 0.261461
# Early stopping, best iteration is:
# [178]	valid_0's auc_mu: 0.987508	valid_0's multi_logloss: 0.262493
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.985962	valid_0's multi_logloss: 0.285027
# [200]	valid_0's auc_mu: 0.986353	valid_0's multi_logloss: 0.269907
# Early stopping, best iteration is:
# [182]	valid_0's auc_mu: 0.986526	valid_0's multi_logloss: 0.270095
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.982417	valid_0's multi_logloss: 0.339982
# [200]	valid_0's auc_mu: 0.984789	valid_0's multi_logloss: 0.292868
# [300]	valid_0's auc_mu: 0.985743	valid_0's multi_logloss: 0.277585
# Early stopping, best iteration is:
# [364]	valid_0's auc_mu: 0.986119	valid_0's multi_logloss: 0.272378
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.982419	valid_0's multi_logloss: 0.34305
# [200]	valid_0's auc_mu: 0.984449	valid_0's multi_logloss: 0.298968
# [300]	valid_0's auc_mu: 0.98561	valid_0's multi_logloss: 0.282169
# [400]	valid_0's auc_mu: 0.98625	valid_0's multi_logloss: 0.27499
# Early stopping, best iteration is:
# [403]	valid_0's auc_mu: 0.986316	valid_0's multi_logloss: 0.274667
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.981549	valid_0's multi_logloss: 0.347683
# [200]	valid_0's auc_mu: 0.983235	valid_0's multi_logloss: 0.306177
# [300]	valid_0's auc_mu: 0.983933	valid_0's multi_logloss: 0.294205
# Early stopping, best iteration is:
# [319]	valid_0's auc_mu: 0.984246	valid_0's multi_logloss: 0.291513
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.980727	valid_0's multi_logloss: 0.38266
# [200]	valid_0's auc_mu: 0.98384	valid_0's multi_logloss: 0.318422
# [300]	valid_0's auc_mu: 0.985161	valid_0's multi_logloss: 0.291585
# [400]	valid_0's auc_mu: 0.98612	valid_0's multi_logloss: 0.276547
# [500]	valid_0's auc_mu: 0.986473	valid_0's multi_logloss: 0.26843
# Early stopping, best iteration is:
# [487]	valid_0's auc_mu: 0.986542	valid_0's multi_logloss: 0.268802
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.976857	valid_0's multi_logloss: 0.426081
# [200]	valid_0's auc_mu: 0.981754	valid_0's multi_logloss: 0.346376
# [300]	valid_0's auc_mu: 0.983511	valid_0's multi_logloss: 0.314021
# [400]	valid_0's auc_mu: 0.984523	valid_0's multi_logloss: 0.295424
# [500]	valid_0's auc_mu: 0.985168	valid_0's multi_logloss: 0.284453
# Early stopping, best iteration is:
# [511]	valid_0's auc_mu: 0.985303	valid_0's multi_logloss: 0.28341
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.975634	valid_0's multi_logloss: 0.431104
# [200]	valid_0's auc_mu: 0.980036	valid_0's multi_logloss: 0.352006
# [300]	valid_0's auc_mu: 0.981912	valid_0's multi_logloss: 0.319257
# [400]	valid_0's auc_mu: 0.9828	valid_0's multi_logloss: 0.304133
# [500]	valid_0's auc_mu: 0.983117	valid_0's multi_logloss: 0.297034
# [600]	valid_0's auc_mu: 0.983491	valid_0's multi_logloss: 0.291518
# Early stopping, best iteration is:
# [659]	valid_0's auc_mu: 0.983789	valid_0's multi_logloss: 0.28928
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.987351	valid_0's multi_logloss: 0.278382
# [200]	valid_0's auc_mu: 0.98929	valid_0's multi_logloss: 0.238078
# [300]	valid_0's auc_mu: 0.990044	valid_0's multi_logloss: 0.225971
# Early stopping, best iteration is:
# [302]	valid_0's auc_mu: 0.990061	valid_0's multi_logloss: 0.225742
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.985265	valid_0's multi_logloss: 0.293371
# [200]	valid_0's auc_mu: 0.987551	valid_0's multi_logloss: 0.249372
# Early stopping, best iteration is:
# [209]	valid_0's auc_mu: 0.987689	valid_0's multi_logloss: 0.247545
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.985474	valid_0's multi_logloss: 0.293377
# [200]	valid_0's auc_mu: 0.986611	valid_0's multi_logloss: 0.263868
# Early stopping, best iteration is:
# [178]	valid_0's auc_mu: 0.986681	valid_0's multi_logloss: 0.26571
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.988444	valid_0's multi_logloss: 0.275961
# [200]	valid_0's auc_mu: 0.989254	valid_0's multi_logloss: 0.25478
# Early stopping, best iteration is:
# [216]	valid_0's auc_mu: 0.989291	valid_0's multi_logloss: 0.253267
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.986728	valid_0's multi_logloss: 0.29303
# [200]	valid_0's auc_mu: 0.987001	valid_0's multi_logloss: 0.27253
# Early stopping, best iteration is:
# [194]	valid_0's auc_mu: 0.98707	valid_0's multi_logloss: 0.273249
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.985014	valid_0's multi_logloss: 0.302823
# [200]	valid_0's auc_mu: 0.985357	valid_0's multi_logloss: 0.286318
# [300]	valid_0's auc_mu: 0.985619	valid_0's multi_logloss: 0.281287
# Early stopping, best iteration is:
# [281]	valid_0's auc_mu: 0.985649	valid_0's multi_logloss: 0.281761
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.976567	valid_0's multi_logloss: 0.450571
# [200]	valid_0's auc_mu: 0.979719	valid_0's multi_logloss: 0.392684
# [300]	valid_0's auc_mu: 0.980544	valid_0's multi_logloss: 0.370932
# [400]	valid_0's auc_mu: 0.980992	valid_0's multi_logloss: 0.360605
# [500]	valid_0's auc_mu: 0.981274	valid_0's multi_logloss: 0.355666
# Early stopping, best iteration is:
# [556]	valid_0's auc_mu: 0.981301	valid_0's multi_logloss: 0.35509
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.97435	valid_0's multi_logloss: 0.456124
# [200]	valid_0's auc_mu: 0.97816	valid_0's multi_logloss: 0.401412
# [300]	valid_0's auc_mu: 0.979316	valid_0's multi_logloss: 0.378251
# [400]	valid_0's auc_mu: 0.979686	valid_0's multi_logloss: 0.36874
# [500]	valid_0's auc_mu: 0.979928	valid_0's multi_logloss: 0.363538
# Early stopping, best iteration is:
# [510]	valid_0's auc_mu: 0.979957	valid_0's multi_logloss: 0.363124
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.974423	valid_0's multi_logloss: 0.460576
# [200]	valid_0's auc_mu: 0.977196	valid_0's multi_logloss: 0.40225
# [300]	valid_0's auc_mu: 0.978341	valid_0's multi_logloss: 0.380656
# [400]	valid_0's auc_mu: 0.978902	valid_0's multi_logloss: 0.370525
# Early stopping, best iteration is:
# [460]	valid_0's auc_mu: 0.979069	valid_0's multi_logloss: 0.367276
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.977913	valid_0's multi_logloss: 0.425855
# [200]	valid_0's auc_mu: 0.980598	valid_0's multi_logloss: 0.368739
# [300]	valid_0's auc_mu: 0.980857	valid_0's multi_logloss: 0.352925
# [400]	valid_0's auc_mu: 0.981188	valid_0's multi_logloss: 0.344024
# Early stopping, best iteration is:
# [400]	valid_0's auc_mu: 0.981188	valid_0's multi_logloss: 0.344024
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.975617	valid_0's multi_logloss: 0.435243
# [200]	valid_0's auc_mu: 0.978431	valid_0's multi_logloss: 0.386055
# [300]	valid_0's auc_mu: 0.979385	valid_0's multi_logloss: 0.366978
# [400]	valid_0's auc_mu: 0.980073	valid_0's multi_logloss: 0.354077
# [500]	valid_0's auc_mu: 0.980383	valid_0's multi_logloss: 0.347485
# Early stopping, best iteration is:
# [561]	valid_0's auc_mu: 0.980476	valid_0's multi_logloss: 0.344709
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.976211	valid_0's multi_logloss: 0.430084
# [200]	valid_0's auc_mu: 0.978258	valid_0's multi_logloss: 0.377267
# [300]	valid_0's auc_mu: 0.979109	valid_0's multi_logloss: 0.359568
# [400]	valid_0's auc_mu: 0.979564	valid_0's multi_logloss: 0.35069
# [500]	valid_0's auc_mu: 0.979894	valid_0's multi_logloss: 0.345544
# Early stopping, best iteration is:
# [510]	valid_0's auc_mu: 0.979899	valid_0's multi_logloss: 0.345397
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.97998	valid_0's multi_logloss: 0.391024
# [200]	valid_0's auc_mu: 0.983387	valid_0's multi_logloss: 0.328227
# [300]	valid_0's auc_mu: 0.984916	valid_0's multi_logloss: 0.302773
# [400]	valid_0's auc_mu: 0.985491	valid_0's multi_logloss: 0.291228
# [500]	valid_0's auc_mu: 0.985886	valid_0's multi_logloss: 0.283608
# Early stopping, best iteration is:
# [534]	valid_0's auc_mu: 0.985964	valid_0's multi_logloss: 0.281751
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.979331	valid_0's multi_logloss: 0.396584
# [200]	valid_0's auc_mu: 0.982998	valid_0's multi_logloss: 0.334875
# [300]	valid_0's auc_mu: 0.984736	valid_0's multi_logloss: 0.308002
# [400]	valid_0's auc_mu: 0.985354	valid_0's multi_logloss: 0.29581
# [500]	valid_0's auc_mu: 0.985815	valid_0's multi_logloss: 0.287996
# [600]	valid_0's auc_mu: 0.986229	valid_0's multi_logloss: 0.281757
# [700]	valid_0's auc_mu: 0.986469	valid_0's multi_logloss: 0.278474
# Early stopping, best iteration is:
# [692]	valid_0's auc_mu: 0.986472	valid_0's multi_logloss: 0.278752
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.977504	valid_0's multi_logloss: 0.40238
# [200]	valid_0's auc_mu: 0.981324	valid_0's multi_logloss: 0.339841
# Early stopping, best iteration is:
# [243]	valid_0's auc_mu: 0.982061	valid_0's multi_logloss: 0.327619
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58555
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58555
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.968734	valid_0's multi_logloss: 0.547819
# [200]	valid_0's auc_mu: 0.97554	valid_0's multi_logloss: 0.462374
# [300]	valid_0's auc_mu: 0.977734	valid_0's multi_logloss: 0.419534
# [400]	valid_0's auc_mu: 0.979295	valid_0's multi_logloss: 0.391415
# [500]	valid_0's auc_mu: 0.979831	valid_0's multi_logloss: 0.374553
# [600]	valid_0's auc_mu: 0.98054	valid_0's multi_logloss: 0.361522
# [700]	valid_0's auc_mu: 0.980927	valid_0's multi_logloss: 0.352327
# [800]	valid_0's auc_mu: 0.981491	valid_0's multi_logloss: 0.342201
# [900]	valid_0's auc_mu: 0.981969	valid_0's multi_logloss: 0.333421
# [1000]	valid_0's auc_mu: 0.982327	valid_0's multi_logloss: 0.327683
# [1100]	valid_0's auc_mu: 0.982539	valid_0's multi_logloss: 0.323408
# [1200]	valid_0's auc_mu: 0.98279	valid_0's multi_logloss: 0.319446
# Early stopping, best iteration is:
# [1247]	valid_0's auc_mu: 0.982968	valid_0's multi_logloss: 0.31778
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.967	valid_0's multi_logloss: 0.542763
# [200]	valid_0's auc_mu: 0.973499	valid_0's multi_logloss: 0.465546
# [300]	valid_0's auc_mu: 0.975747	valid_0's multi_logloss: 0.425364
# [400]	valid_0's auc_mu: 0.977353	valid_0's multi_logloss: 0.400129
# [500]	valid_0's auc_mu: 0.978548	valid_0's multi_logloss: 0.381086
# [600]	valid_0's auc_mu: 0.979547	valid_0's multi_logloss: 0.367028
# [700]	valid_0's auc_mu: 0.980303	valid_0's multi_logloss: 0.355601
# [800]	valid_0's auc_mu: 0.981032	valid_0's multi_logloss: 0.346029
# [900]	valid_0's auc_mu: 0.981527	valid_0's multi_logloss: 0.339328
# [1000]	valid_0's auc_mu: 0.981896	valid_0's multi_logloss: 0.333809
# [1100]	valid_0's auc_mu: 0.982262	valid_0's multi_logloss: 0.329292
# [1200]	valid_0's auc_mu: 0.982677	valid_0's multi_logloss: 0.325023
# [1300]	valid_0's auc_mu: 0.98305	valid_0's multi_logloss: 0.320638
# [1400]	valid_0's auc_mu: 0.983351	valid_0's multi_logloss: 0.315976
# Early stopping, best iteration is:
# [1435]	valid_0's auc_mu: 0.983443	valid_0's multi_logloss: 0.314676
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.966514	valid_0's multi_logloss: 0.553003
# [200]	valid_0's auc_mu: 0.972711	valid_0's multi_logloss: 0.471285
# [300]	valid_0's auc_mu: 0.975005	valid_0's multi_logloss: 0.429501
# [400]	valid_0's auc_mu: 0.976583	valid_0's multi_logloss: 0.404619
# [500]	valid_0's auc_mu: 0.977575	valid_0's multi_logloss: 0.386648
# [600]	valid_0's auc_mu: 0.978523	valid_0's multi_logloss: 0.371829
# [700]	valid_0's auc_mu: 0.979291	valid_0's multi_logloss: 0.359808
# [800]	valid_0's auc_mu: 0.979896	valid_0's multi_logloss: 0.350224
# [900]	valid_0's auc_mu: 0.98038	valid_0's multi_logloss: 0.343211
# [1000]	valid_0's auc_mu: 0.980917	valid_0's multi_logloss: 0.336527
# [1100]	valid_0's auc_mu: 0.981134	valid_0's multi_logloss: 0.331922
# [1200]	valid_0's auc_mu: 0.981371	valid_0's multi_logloss: 0.327872
# [1300]	valid_0's auc_mu: 0.981649	valid_0's multi_logloss: 0.324308
# [1400]	valid_0's auc_mu: 0.981889	valid_0's multi_logloss: 0.321237
# [1500]	valid_0's auc_mu: 0.982055	valid_0's multi_logloss: 0.318991
# [1600]	valid_0's auc_mu: 0.982213	valid_0's multi_logloss: 0.316726
# [1700]	valid_0's auc_mu: 0.982353	valid_0's multi_logloss: 0.314548
# [1800]	valid_0's auc_mu: 0.982489	valid_0's multi_logloss: 0.312492
# Early stopping, best iteration is:
# [1799]	valid_0's auc_mu: 0.982492	valid_0's multi_logloss: 0.312499
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.938177	valid_0's multi_logloss: 0.736779
# [200]	valid_0's auc_mu: 0.941917	valid_0's multi_logloss: 0.698641
# [300]	valid_0's auc_mu: 0.943015	valid_0's multi_logloss: 0.682658
# Early stopping, best iteration is:
# [354]	valid_0's auc_mu: 0.9434	valid_0's multi_logloss: 0.67618
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.939418	valid_0's multi_logloss: 0.728309
# Early stopping, best iteration is:
# [165]	valid_0's auc_mu: 0.942397	valid_0's multi_logloss: 0.690425
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.938054	valid_0's multi_logloss: 0.736427
# [200]	valid_0's auc_mu: 0.943989	valid_0's multi_logloss: 0.692093
# Early stopping, best iteration is:
# [209]	valid_0's auc_mu: 0.944092	valid_0's multi_logloss: 0.690319
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.985093	valid_0's multi_logloss: 0.347851
# [200]	valid_0's auc_mu: 0.987663	valid_0's multi_logloss: 0.287212
# [300]	valid_0's auc_mu: 0.988702	valid_0's multi_logloss: 0.262824
# [400]	valid_0's auc_mu: 0.989442	valid_0's multi_logloss: 0.247032
# [500]	valid_0's auc_mu: 0.989765	valid_0's multi_logloss: 0.238952
# [600]	valid_0's auc_mu: 0.989916	valid_0's multi_logloss: 0.234618
# [700]	valid_0's auc_mu: 0.990176	valid_0's multi_logloss: 0.229819
# Early stopping, best iteration is:
# [671]	valid_0's auc_mu: 0.990188	valid_0's multi_logloss: 0.230907
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.984559	valid_0's multi_logloss: 0.354241
# [200]	valid_0's auc_mu: 0.985673	valid_0's multi_logloss: 0.302037
# [300]	valid_0's auc_mu: 0.986561	valid_0's multi_logloss: 0.279642
# [400]	valid_0's auc_mu: 0.98698	valid_0's multi_logloss: 0.267575
# Early stopping, best iteration is:
# [405]	valid_0's auc_mu: 0.98703	valid_0's multi_logloss: 0.267138
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.983222	valid_0's multi_logloss: 0.360168
# [200]	valid_0's auc_mu: 0.984999	valid_0's multi_logloss: 0.308304
# [300]	valid_0's auc_mu: 0.985868	valid_0's multi_logloss: 0.286905
# [400]	valid_0's auc_mu: 0.986103	valid_0's multi_logloss: 0.27585
# Early stopping, best iteration is:
# [384]	valid_0's auc_mu: 0.986208	valid_0's multi_logloss: 0.276768
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.90825	valid_0's multi_logloss: 0.862337
# [200]	valid_0's auc_mu: 0.908949	valid_0's multi_logloss: 0.856193
# [300]	valid_0's auc_mu: 0.909997	valid_0's multi_logloss: 0.855419
# Early stopping, best iteration is:
# [288]	valid_0's auc_mu: 0.909997	valid_0's multi_logloss: 0.855446
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.916194	valid_0's multi_logloss: 0.851104
# Early stopping, best iteration is:
# [118]	valid_0's auc_mu: 0.916675	valid_0's multi_logloss: 0.848871
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.90899	valid_0's multi_logloss: 0.857181
# Early stopping, best iteration is:
# [169]	valid_0's auc_mu: 0.909653	valid_0's multi_logloss: 0.852444
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.991112	valid_0's multi_logloss: 0.214092
# Early stopping, best iteration is:
# [85]	valid_0's auc_mu: 0.991264	valid_0's multi_logloss: 0.213705
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.990571	valid_0's multi_logloss: 0.230249
# Early stopping, best iteration is:
# [93]	valid_0's auc_mu: 0.990644	valid_0's multi_logloss: 0.229161
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [65]	valid_0's auc_mu: 0.988584	valid_0's multi_logloss: 0.248512
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.914844	valid_0's multi_logloss: 0.995757
# Early stopping, best iteration is:
# [80]	valid_0's auc_mu: 0.914852	valid_0's multi_logloss: 0.99717
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [55]	valid_0's auc_mu: 0.920537	valid_0's multi_logloss: 0.953367
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [54]	valid_0's auc_mu: 0.919403	valid_0's multi_logloss: 1.04131
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.98282	valid_0's multi_logloss: 0.347977
# [200]	valid_0's auc_mu: 0.985364	valid_0's multi_logloss: 0.291978
# [300]	valid_0's auc_mu: 0.986469	valid_0's multi_logloss: 0.269411
# [400]	valid_0's auc_mu: 0.987168	valid_0's multi_logloss: 0.257771
# [500]	valid_0's auc_mu: 0.987389	valid_0's multi_logloss: 0.252102
# Early stopping, best iteration is:
# [510]	valid_0's auc_mu: 0.987501	valid_0's multi_logloss: 0.250985
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.981691	valid_0's multi_logloss: 0.361178
# [200]	valid_0's auc_mu: 0.985212	valid_0's multi_logloss: 0.29981
# [300]	valid_0's auc_mu: 0.986345	valid_0's multi_logloss: 0.275304
# [400]	valid_0's auc_mu: 0.986966	valid_0's multi_logloss: 0.263565
# [500]	valid_0's auc_mu: 0.987397	valid_0's multi_logloss: 0.257413
# Early stopping, best iteration is:
# [483]	valid_0's auc_mu: 0.987465	valid_0's multi_logloss: 0.25781
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.980383	valid_0's multi_logloss: 0.364731
# [200]	valid_0's auc_mu: 0.98296	valid_0's multi_logloss: 0.309423
# [300]	valid_0's auc_mu: 0.983718	valid_0's multi_logloss: 0.291255
# [400]	valid_0's auc_mu: 0.984408	valid_0's multi_logloss: 0.280821
# [500]	valid_0's auc_mu: 0.984869	valid_0's multi_logloss: 0.277303
# Early stopping, best iteration is:
# [558]	valid_0's auc_mu: 0.985047	valid_0's multi_logloss: 0.276117
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.900076	valid_0's multi_logloss: 1.11309
# Early stopping, best iteration is:
# [116]	valid_0's auc_mu: 0.900247	valid_0's multi_logloss: 1.11205
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.908219	valid_0's multi_logloss: 1.10178
# Early stopping, best iteration is:
# [110]	valid_0's auc_mu: 0.908499	valid_0's multi_logloss: 1.10071
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.895313	valid_0's multi_logloss: 1.12179
# Early stopping, best iteration is:
# [112]	valid_0's auc_mu: 0.895322	valid_0's multi_logloss: 1.12099
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.978954	valid_0's multi_logloss: 0.424616
# [200]	valid_0's auc_mu: 0.98399	valid_0's multi_logloss: 0.349873
# [300]	valid_0's auc_mu: 0.98578	valid_0's multi_logloss: 0.317664
# [400]	valid_0's auc_mu: 0.986609	valid_0's multi_logloss: 0.301417
# [500]	valid_0's auc_mu: 0.987116	valid_0's multi_logloss: 0.290462
# [600]	valid_0's auc_mu: 0.987409	valid_0's multi_logloss: 0.282575
# [700]	valid_0's auc_mu: 0.987629	valid_0's multi_logloss: 0.277655
# [800]	valid_0's auc_mu: 0.987779	valid_0's multi_logloss: 0.273811
# [900]	valid_0's auc_mu: 0.987926	valid_0's multi_logloss: 0.271043
# Early stopping, best iteration is:
# [877]	valid_0's auc_mu: 0.987946	valid_0's multi_logloss: 0.27154
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.977518	valid_0's multi_logloss: 0.43229
# [200]	valid_0's auc_mu: 0.981369	valid_0's multi_logloss: 0.363739
# [300]	valid_0's auc_mu: 0.982854	valid_0's multi_logloss: 0.333708
# [400]	valid_0's auc_mu: 0.98361	valid_0's multi_logloss: 0.317478
# [500]	valid_0's auc_mu: 0.984297	valid_0's multi_logloss: 0.306426
# [600]	valid_0's auc_mu: 0.98468	valid_0's multi_logloss: 0.298996
# Early stopping, best iteration is:
# [652]	valid_0's auc_mu: 0.984861	valid_0's multi_logloss: 0.296194
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.97644	valid_0's multi_logloss: 0.433801
# [200]	valid_0's auc_mu: 0.980618	valid_0's multi_logloss: 0.367042
# [300]	valid_0's auc_mu: 0.982647	valid_0's multi_logloss: 0.335319
# [400]	valid_0's auc_mu: 0.983539	valid_0's multi_logloss: 0.320064
# [500]	valid_0's auc_mu: 0.983966	valid_0's multi_logloss: 0.310578
# [600]	valid_0's auc_mu: 0.984164	valid_0's multi_logloss: 0.304958
# [700]	valid_0's auc_mu: 0.984392	valid_0's multi_logloss: 0.300927
# [800]	valid_0's auc_mu: 0.984551	valid_0's multi_logloss: 0.297925
# Early stopping, best iteration is:
# [867]	valid_0's auc_mu: 0.984695	valid_0's multi_logloss: 0.296251
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.985748	valid_0's multi_logloss: 0.332543
# [200]	valid_0's auc_mu: 0.987417	valid_0's multi_logloss: 0.284996
# [300]	valid_0's auc_mu: 0.988006	valid_0's multi_logloss: 0.267679
# [400]	valid_0's auc_mu: 0.988433	valid_0's multi_logloss: 0.258347
# Early stopping, best iteration is:
# [378]	valid_0's auc_mu: 0.988449	valid_0's multi_logloss: 0.259659
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.983	valid_0's multi_logloss: 0.349104
# [200]	valid_0's auc_mu: 0.985059	valid_0's multi_logloss: 0.300402
# [300]	valid_0's auc_mu: 0.985796	valid_0's multi_logloss: 0.282624
# [400]	valid_0's auc_mu: 0.986273	valid_0's multi_logloss: 0.272377
# [500]	valid_0's auc_mu: 0.98638	valid_0's multi_logloss: 0.268289
# [600]	valid_0's auc_mu: 0.986512	valid_0's multi_logloss: 0.265261
# Early stopping, best iteration is:
# [587]	valid_0's auc_mu: 0.986533	valid_0's multi_logloss: 0.265567
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.982308	valid_0's multi_logloss: 0.353305
# [200]	valid_0's auc_mu: 0.984108	valid_0's multi_logloss: 0.307263
# [300]	valid_0's auc_mu: 0.984918	valid_0's multi_logloss: 0.290789
# [400]	valid_0's auc_mu: 0.985257	valid_0's multi_logloss: 0.283861
# Early stopping, best iteration is:
# [392]	valid_0's auc_mu: 0.985288	valid_0's multi_logloss: 0.284089
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58555
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.987627	valid_0's multi_logloss: 0.306839
# Early stopping, best iteration is:
# [158]	valid_0's auc_mu: 0.988155	valid_0's multi_logloss: 0.29194
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.986773	valid_0's multi_logloss: 0.313881
# Early stopping, best iteration is:
# [159]	valid_0's auc_mu: 0.987196	valid_0's multi_logloss: 0.297742
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.984128	valid_0's multi_logloss: 0.326826
# [200]	valid_0's auc_mu: 0.984585	valid_0's multi_logloss: 0.309673
# Early stopping, best iteration is:
# [217]	valid_0's auc_mu: 0.984604	valid_0's multi_logloss: 0.308945
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.981652	valid_0's multi_logloss: 0.391818
# [200]	valid_0's auc_mu: 0.984387	valid_0's multi_logloss: 0.338639
# [300]	valid_0's auc_mu: 0.98539	valid_0's multi_logloss: 0.31927
# [400]	valid_0's auc_mu: 0.98558	valid_0's multi_logloss: 0.312047
# [500]	valid_0's auc_mu: 0.985785	valid_0's multi_logloss: 0.306862
# Early stopping, best iteration is:
# [500]	valid_0's auc_mu: 0.985785	valid_0's multi_logloss: 0.306862
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.981737	valid_0's multi_logloss: 0.399884
# [200]	valid_0's auc_mu: 0.983934	valid_0's multi_logloss: 0.347009
# [300]	valid_0's auc_mu: 0.984652	valid_0's multi_logloss: 0.326599
# [400]	valid_0's auc_mu: 0.984888	valid_0's multi_logloss: 0.317744
# [500]	valid_0's auc_mu: 0.98502	valid_0's multi_logloss: 0.313162
# Early stopping, best iteration is:
# [527]	valid_0's auc_mu: 0.98507	valid_0's multi_logloss: 0.312098
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.980137	valid_0's multi_logloss: 0.400574
# [200]	valid_0's auc_mu: 0.982646	valid_0's multi_logloss: 0.350557
# [300]	valid_0's auc_mu: 0.9833	valid_0's multi_logloss: 0.333849
# [400]	valid_0's auc_mu: 0.983663	valid_0's multi_logloss: 0.323835
# [500]	valid_0's auc_mu: 0.98377	valid_0's multi_logloss: 0.319471
# [600]	valid_0's auc_mu: 0.983795	valid_0's multi_logloss: 0.317132
# [700]	valid_0's auc_mu: 0.983805	valid_0's multi_logloss: 0.315678
# Early stopping, best iteration is:
# [684]	valid_0's auc_mu: 0.98382	valid_0's multi_logloss: 0.315813
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.972647	valid_0's multi_logloss: 0.508882
# [200]	valid_0's auc_mu: 0.977932	valid_0's multi_logloss: 0.436336
# [300]	valid_0's auc_mu: 0.979401	valid_0's multi_logloss: 0.404936
# [400]	valid_0's auc_mu: 0.979933	valid_0's multi_logloss: 0.387884
# [500]	valid_0's auc_mu: 0.980359	valid_0's multi_logloss: 0.377342
# [600]	valid_0's auc_mu: 0.980587	valid_0's multi_logloss: 0.370106
# Early stopping, best iteration is:
# [661]	valid_0's auc_mu: 0.980708	valid_0's multi_logloss: 0.366485
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.969413	valid_0's multi_logloss: 0.513071
# [200]	valid_0's auc_mu: 0.975494	valid_0's multi_logloss: 0.440633
# [300]	valid_0's auc_mu: 0.977206	valid_0's multi_logloss: 0.411304
# [400]	valid_0's auc_mu: 0.97783	valid_0's multi_logloss: 0.396735
# [500]	valid_0's auc_mu: 0.978232	valid_0's multi_logloss: 0.386244
# [600]	valid_0's auc_mu: 0.978547	valid_0's multi_logloss: 0.378093
# [700]	valid_0's auc_mu: 0.978791	valid_0's multi_logloss: 0.372798
# [800]	valid_0's auc_mu: 0.978847	valid_0's multi_logloss: 0.370242
# Early stopping, best iteration is:
# [777]	valid_0's auc_mu: 0.978872	valid_0's multi_logloss: 0.370843
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.970526	valid_0's multi_logloss: 0.517173
# [200]	valid_0's auc_mu: 0.974589	valid_0's multi_logloss: 0.44375
# [300]	valid_0's auc_mu: 0.976079	valid_0's multi_logloss: 0.414634
# [400]	valid_0's auc_mu: 0.977005	valid_0's multi_logloss: 0.397319
# [500]	valid_0's auc_mu: 0.977567	valid_0's multi_logloss: 0.387322
# [600]	valid_0's auc_mu: 0.977936	valid_0's multi_logloss: 0.380449
# [700]	valid_0's auc_mu: 0.978129	valid_0's multi_logloss: 0.375664
# [800]	valid_0's auc_mu: 0.978295	valid_0's multi_logloss: 0.372363
# Early stopping, best iteration is:
# [776]	valid_0's auc_mu: 0.978307	valid_0's multi_logloss: 0.372877
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.934533	valid_0's multi_logloss: 0.807689
# [200]	valid_0's auc_mu: 0.935532	valid_0's multi_logloss: 0.794396
# Early stopping, best iteration is:
# [216]	valid_0's auc_mu: 0.935767	valid_0's multi_logloss: 0.79394
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.93973	valid_0's multi_logloss: 0.802974
# Early stopping, best iteration is:
# [142]	valid_0's auc_mu: 0.940673	valid_0's multi_logloss: 0.793173
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.940425	valid_0's multi_logloss: 0.796093
# [200]	valid_0's auc_mu: 0.941582	valid_0's multi_logloss: 0.783187
# Early stopping, best iteration is:
# [189]	valid_0's auc_mu: 0.941588	valid_0's multi_logloss: 0.783433
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [47]	valid_0's auc_mu: 0.915082	valid_0's multi_logloss: 1.06926
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [66]	valid_0's auc_mu: 0.924407	valid_0's multi_logloss: 1.05429
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [16]	valid_0's auc_mu: 0.912503	valid_0's multi_logloss: 1.15985
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.982744	valid_0's multi_logloss: 0.36165
# [200]	valid_0's auc_mu: 0.985322	valid_0's multi_logloss: 0.300602
# [300]	valid_0's auc_mu: 0.986348	valid_0's multi_logloss: 0.278687
# [400]	valid_0's auc_mu: 0.986995	valid_0's multi_logloss: 0.2671
# [500]	valid_0's auc_mu: 0.987413	valid_0's multi_logloss: 0.259404
# Early stopping, best iteration is:
# [568]	valid_0's auc_mu: 0.987633	valid_0's multi_logloss: 0.256332
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.980651	valid_0's multi_logloss: 0.373596
# [200]	valid_0's auc_mu: 0.984171	valid_0's multi_logloss: 0.311471
# [300]	valid_0's auc_mu: 0.985667	valid_0's multi_logloss: 0.286135
# [400]	valid_0's auc_mu: 0.986239	valid_0's multi_logloss: 0.274007
# [500]	valid_0's auc_mu: 0.986581	valid_0's multi_logloss: 0.268409
# Early stopping, best iteration is:
# [492]	valid_0's auc_mu: 0.986606	valid_0's multi_logloss: 0.268579
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.980483	valid_0's multi_logloss: 0.373245
# [200]	valid_0's auc_mu: 0.983038	valid_0's multi_logloss: 0.317262
# [300]	valid_0's auc_mu: 0.983789	valid_0's multi_logloss: 0.299782
# [400]	valid_0's auc_mu: 0.984205	valid_0's multi_logloss: 0.291455
# [500]	valid_0's auc_mu: 0.984404	valid_0's multi_logloss: 0.28663
# [600]	valid_0's auc_mu: 0.984772	valid_0's multi_logloss: 0.283514
# Early stopping, best iteration is:
# [657]	valid_0's auc_mu: 0.984903	valid_0's multi_logloss: 0.282538
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.980927	valid_0's multi_logloss: 0.387189
# [200]	valid_0's auc_mu: 0.981525	valid_0's multi_logloss: 0.373344
# Early stopping, best iteration is:
# [222]	valid_0's auc_mu: 0.981535	valid_0's multi_logloss: 0.372977
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.979146	valid_0's multi_logloss: 0.394655
# [200]	valid_0's auc_mu: 0.979889	valid_0's multi_logloss: 0.381631
# Early stopping, best iteration is:
# [193]	valid_0's auc_mu: 0.979902	valid_0's multi_logloss: 0.381904
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.978396	valid_0's multi_logloss: 0.399883
# [200]	valid_0's auc_mu: 0.978979	valid_0's multi_logloss: 0.389901
# Early stopping, best iteration is:
# [182]	valid_0's auc_mu: 0.978995	valid_0's multi_logloss: 0.389931
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58555
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.912699	valid_0's multi_logloss: 0.849182
# Early stopping, best iteration is:
# [156]	valid_0's auc_mu: 0.915213	valid_0's multi_logloss: 0.84556
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.917107	valid_0's multi_logloss: 0.844503
# Early stopping, best iteration is:
# [136]	valid_0's auc_mu: 0.917891	valid_0's multi_logloss: 0.841051
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.91018	valid_0's multi_logloss: 0.851174
# Early stopping, best iteration is:
# [121]	valid_0's auc_mu: 0.910636	valid_0's multi_logloss: 0.849271
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.975183	valid_0's multi_logloss: 0.478759
# [200]	valid_0's auc_mu: 0.979074	valid_0's multi_logloss: 0.410527
# [300]	valid_0's auc_mu: 0.980183	valid_0's multi_logloss: 0.383224
# [400]	valid_0's auc_mu: 0.98052	valid_0's multi_logloss: 0.370915
# [500]	valid_0's auc_mu: 0.980767	valid_0's multi_logloss: 0.364229
# [600]	valid_0's auc_mu: 0.981001	valid_0's multi_logloss: 0.359439
# [700]	valid_0's auc_mu: 0.981101	valid_0's multi_logloss: 0.356829
# [800]	valid_0's auc_mu: 0.981171	valid_0's multi_logloss: 0.354787
# [900]	valid_0's auc_mu: 0.981248	valid_0's multi_logloss: 0.353973
# Early stopping, best iteration is:
# [953]	valid_0's auc_mu: 0.98127	valid_0's multi_logloss: 0.353848
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.972913	valid_0's multi_logloss: 0.480531
# [200]	valid_0's auc_mu: 0.976823	valid_0's multi_logloss: 0.41685
# [300]	valid_0's auc_mu: 0.978093	valid_0's multi_logloss: 0.392277
# [400]	valid_0's auc_mu: 0.978441	valid_0's multi_logloss: 0.381691
# [500]	valid_0's auc_mu: 0.978855	valid_0's multi_logloss: 0.374097
# [600]	valid_0's auc_mu: 0.979024	valid_0's multi_logloss: 0.369198
# [700]	valid_0's auc_mu: 0.979242	valid_0's multi_logloss: 0.365535
# Early stopping, best iteration is:
# [699]	valid_0's auc_mu: 0.979243	valid_0's multi_logloss: 0.36556
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.971873	valid_0's multi_logloss: 0.484688
# [200]	valid_0's auc_mu: 0.975699	valid_0's multi_logloss: 0.421823
# [300]	valid_0's auc_mu: 0.976861	valid_0's multi_logloss: 0.397235
# [400]	valid_0's auc_mu: 0.977512	valid_0's multi_logloss: 0.38423
# [500]	valid_0's auc_mu: 0.977878	valid_0's multi_logloss: 0.376645
# [600]	valid_0's auc_mu: 0.978067	valid_0's multi_logloss: 0.373246
# Early stopping, best iteration is:
# [603]	valid_0's auc_mu: 0.97809	valid_0's multi_logloss: 0.373182
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.986705	valid_0's multi_logloss: 0.317107
# [200]	valid_0's auc_mu: 0.988237	valid_0's multi_logloss: 0.272659
# [300]	valid_0's auc_mu: 0.988962	valid_0's multi_logloss: 0.257229
# Early stopping, best iteration is:
# [326]	valid_0's auc_mu: 0.989119	valid_0's multi_logloss: 0.255562
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.984991	valid_0's multi_logloss: 0.326604
# [200]	valid_0's auc_mu: 0.985978	valid_0's multi_logloss: 0.288009
# Early stopping, best iteration is:
# [253]	valid_0's auc_mu: 0.986442	valid_0's multi_logloss: 0.2786
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.984075	valid_0's multi_logloss: 0.329756
# [200]	valid_0's auc_mu: 0.985596	valid_0's multi_logloss: 0.291151
# Early stopping, best iteration is:
# [252]	valid_0's auc_mu: 0.985773	valid_0's multi_logloss: 0.284508
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58555
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58555
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.971949	valid_0's multi_logloss: 0.512137
# [200]	valid_0's auc_mu: 0.97725	valid_0's multi_logloss: 0.430893
# [300]	valid_0's auc_mu: 0.979253	valid_0's multi_logloss: 0.390754
# [400]	valid_0's auc_mu: 0.980076	valid_0's multi_logloss: 0.36831
# [500]	valid_0's auc_mu: 0.981129	valid_0's multi_logloss: 0.352222
# [600]	valid_0's auc_mu: 0.981715	valid_0's multi_logloss: 0.339915
# [700]	valid_0's auc_mu: 0.982106	valid_0's multi_logloss: 0.330709
# [800]	valid_0's auc_mu: 0.982563	valid_0's multi_logloss: 0.322805
# [900]	valid_0's auc_mu: 0.982936	valid_0's multi_logloss: 0.316389
# [1000]	valid_0's auc_mu: 0.983177	valid_0's multi_logloss: 0.311621
# Early stopping, best iteration is:
# [1067]	valid_0's auc_mu: 0.98334	valid_0's multi_logloss: 0.309014
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.968359	valid_0's multi_logloss: 0.519092
# [200]	valid_0's auc_mu: 0.975234	valid_0's multi_logloss: 0.438005
# [300]	valid_0's auc_mu: 0.977382	valid_0's multi_logloss: 0.399885
# [400]	valid_0's auc_mu: 0.979023	valid_0's multi_logloss: 0.37605
# [500]	valid_0's auc_mu: 0.979909	valid_0's multi_logloss: 0.359552
# [600]	valid_0's auc_mu: 0.980869	valid_0's multi_logloss: 0.345075
# [700]	valid_0's auc_mu: 0.981485	valid_0's multi_logloss: 0.334689
# [800]	valid_0's auc_mu: 0.981932	valid_0's multi_logloss: 0.326676
# [900]	valid_0's auc_mu: 0.982317	valid_0's multi_logloss: 0.320776
# [1000]	valid_0's auc_mu: 0.982838	valid_0's multi_logloss: 0.315151
# [1100]	valid_0's auc_mu: 0.982975	valid_0's multi_logloss: 0.311152
# Early stopping, best iteration is:
# [1085]	valid_0's auc_mu: 0.983011	valid_0's multi_logloss: 0.311788
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.969353	valid_0's multi_logloss: 0.520477
# [200]	valid_0's auc_mu: 0.974281	valid_0's multi_logloss: 0.438554
# [300]	valid_0's auc_mu: 0.976737	valid_0's multi_logloss: 0.399059
# [400]	valid_0's auc_mu: 0.978156	valid_0's multi_logloss: 0.37554
# [500]	valid_0's auc_mu: 0.97941	valid_0's multi_logloss: 0.358398
# [600]	valid_0's auc_mu: 0.980053	valid_0's multi_logloss: 0.346551
# [700]	valid_0's auc_mu: 0.980701	valid_0's multi_logloss: 0.336834
# [800]	valid_0's auc_mu: 0.981141	valid_0's multi_logloss: 0.329702
# [900]	valid_0's auc_mu: 0.981472	valid_0's multi_logloss: 0.324153
# [1000]	valid_0's auc_mu: 0.981898	valid_0's multi_logloss: 0.318677
# [1100]	valid_0's auc_mu: 0.982087	valid_0's multi_logloss: 0.315183
# [1200]	valid_0's auc_mu: 0.982363	valid_0's multi_logloss: 0.312014
# [1300]	valid_0's auc_mu: 0.982565	valid_0's multi_logloss: 0.309004
# [1400]	valid_0's auc_mu: 0.982679	valid_0's multi_logloss: 0.306807
# [1500]	valid_0's auc_mu: 0.982863	valid_0's multi_logloss: 0.305044
# [1600]	valid_0's auc_mu: 0.982887	valid_0's multi_logloss: 0.303888
# Early stopping, best iteration is:
# [1578]	valid_0's auc_mu: 0.982905	valid_0's multi_logloss: 0.304038
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.977003	valid_0's multi_logloss: 0.441961
# [200]	valid_0's auc_mu: 0.978635	valid_0's multi_logloss: 0.405558
# Early stopping, best iteration is:
# [225]	valid_0's auc_mu: 0.978694	valid_0's multi_logloss: 0.403523
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.975723	valid_0's multi_logloss: 0.439064
# [200]	valid_0's auc_mu: 0.97724	valid_0's multi_logloss: 0.406753
# Early stopping, best iteration is:
# [258]	valid_0's auc_mu: 0.977361	valid_0's multi_logloss: 0.402752
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.974823	valid_0's multi_logloss: 0.44216
# [200]	valid_0's auc_mu: 0.976529	valid_0's multi_logloss: 0.409438
# Early stopping, best iteration is:
# [204]	valid_0's auc_mu: 0.976569	valid_0's multi_logloss: 0.409203
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58555
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.866411	valid_0's multi_logloss: 1.20912
# Early stopping, best iteration is:
# [95]	valid_0's auc_mu: 0.866411	valid_0's multi_logloss: 1.20991
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.877824	valid_0's multi_logloss: 1.22392
# Early stopping, best iteration is:
# [87]	valid_0's auc_mu: 0.87847	valid_0's multi_logloss: 1.22649
# Training until validation scores don't improve for 30 rounds
# ...
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.98176	valid_0's multi_logloss: 0.383816
# Early stopping, best iteration is:
# [157]	valid_0's auc_mu: 0.98217	valid_0's multi_logloss: 0.373167
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.979209	valid_0's multi_logloss: 0.39595
# [200]	valid_0's auc_mu: 0.980086	valid_0's multi_logloss: 0.379071
# Early stopping, best iteration is:
# [198]	valid_0's auc_mu: 0.980105	valid_0's multi_logloss: 0.379203
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.978696	valid_0's multi_logloss: 0.396718
# [200]	valid_0's auc_mu: 0.979497	valid_0's multi_logloss: 0.384617
# Early stopping, best iteration is:
# [178]	valid_0's auc_mu: 0.979501	valid_0's multi_logloss: 0.384976
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.986954	valid_0's multi_logloss: 0.28099
# [200]	valid_0's auc_mu: 0.989056	valid_0's multi_logloss: 0.234417
# [300]	valid_0's auc_mu: 0.989713	valid_0's multi_logloss: 0.225981
# Early stopping, best iteration is:
# [303]	valid_0's auc_mu: 0.989807	valid_0's multi_logloss: 0.225474
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.985953	valid_0's multi_logloss: 0.286075
# [200]	valid_0's auc_mu: 0.988274	valid_0's multi_logloss: 0.238965
# Early stopping, best iteration is:
# [251]	valid_0's auc_mu: 0.988649	valid_0's multi_logloss: 0.234118
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.984678	valid_0's multi_logloss: 0.295892
# [200]	valid_0's auc_mu: 0.986569	valid_0's multi_logloss: 0.260316
# Early stopping, best iteration is:
# [250]	valid_0's auc_mu: 0.986841	valid_0's multi_logloss: 0.258874
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.939949	valid_0's multi_logloss: 0.716963
# [200]	valid_0's auc_mu: 0.941402	valid_0's multi_logloss: 0.692662
# [300]	valid_0's auc_mu: 0.942121	valid_0's multi_logloss: 0.682507
# Early stopping, best iteration is:
# [356]	valid_0's auc_mu: 0.942218	valid_0's multi_logloss: 0.679339
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.941726	valid_0's multi_logloss: 0.699809
# Early stopping, best iteration is:
# [141]	valid_0's auc_mu: 0.942186	valid_0's multi_logloss: 0.683617
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.941325	valid_0's multi_logloss: 0.711244
# [200]	valid_0's auc_mu: 0.943479	valid_0's multi_logloss: 0.684722
# Early stopping, best iteration is:
# [189]	valid_0's auc_mu: 0.943519	valid_0's multi_logloss: 0.686245
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.979448	valid_0's multi_logloss: 0.413999
# [200]	valid_0's auc_mu: 0.980538	valid_0's multi_logloss: 0.38723
# Early stopping, best iteration is:
# [243]	valid_0's auc_mu: 0.98056	valid_0's multi_logloss: 0.386492
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.976571	valid_0's multi_logloss: 0.422955
# [200]	valid_0's auc_mu: 0.978074	valid_0's multi_logloss: 0.392127
# Early stopping, best iteration is:
# [251]	valid_0's auc_mu: 0.978233	valid_0's multi_logloss: 0.389155
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.975654	valid_0's multi_logloss: 0.428013
# [200]	valid_0's auc_mu: 0.977254	valid_0's multi_logloss: 0.398599
# [300]	valid_0's auc_mu: 0.977398	valid_0's multi_logloss: 0.395779
# Early stopping, best iteration is:
# [308]	valid_0's auc_mu: 0.977409	valid_0's multi_logloss: 0.39577
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.965687	valid_0's multi_logloss: 0.556909
# [200]	valid_0's auc_mu: 0.972127	valid_0's multi_logloss: 0.494003
# [300]	valid_0's auc_mu: 0.973869	valid_0's multi_logloss: 0.46412
# [400]	valid_0's auc_mu: 0.974636	valid_0's multi_logloss: 0.448638
# Early stopping, best iteration is:
# [425]	valid_0's auc_mu: 0.974823	valid_0's multi_logloss: 0.445025
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.964737	valid_0's multi_logloss: 0.549595
# [200]	valid_0's auc_mu: 0.969988	valid_0's multi_logloss: 0.489287
# [300]	valid_0's auc_mu: 0.971919	valid_0's multi_logloss: 0.461138
# [400]	valid_0's auc_mu: 0.972654	valid_0's multi_logloss: 0.446943
# [500]	valid_0's auc_mu: 0.973013	valid_0's multi_logloss: 0.44162
# [600]	valid_0's auc_mu: 0.973108	valid_0's multi_logloss: 0.438823
# [700]	valid_0's auc_mu: 0.973336	valid_0's multi_logloss: 0.43627
# [800]	valid_0's auc_mu: 0.973385	valid_0's multi_logloss: 0.434547
# Early stopping, best iteration is:
# [799]	valid_0's auc_mu: 0.973385	valid_0's multi_logloss: 0.434557
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.965687	valid_0's multi_logloss: 0.557231
# [200]	valid_0's auc_mu: 0.970397	valid_0's multi_logloss: 0.496708
# [300]	valid_0's auc_mu: 0.972343	valid_0's multi_logloss: 0.465976
# Early stopping, best iteration is:
# [353]	valid_0's auc_mu: 0.972771	valid_0's multi_logloss: 0.459154
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.987275	valid_0's multi_logloss: 0.27554
# [200]	valid_0's auc_mu: 0.988079	valid_0's multi_logloss: 0.256795
# Early stopping, best iteration is:
# [178]	valid_0's auc_mu: 0.988158	valid_0's multi_logloss: 0.257912
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.986486	valid_0's multi_logloss: 0.28443
# Early stopping, best iteration is:
# [140]	valid_0's auc_mu: 0.987019	valid_0's multi_logloss: 0.273733
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.984937	valid_0's multi_logloss: 0.293839
# Early stopping, best iteration is:
# [137]	valid_0's auc_mu: 0.985497	valid_0's multi_logloss: 0.282966
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.977664	valid_0's multi_logloss: 0.415539
# [200]	valid_0's auc_mu: 0.981989	valid_0's multi_logloss: 0.337064
# [300]	valid_0's auc_mu: 0.984164	valid_0's multi_logloss: 0.299716
# [400]	valid_0's auc_mu: 0.985066	valid_0's multi_logloss: 0.285153
# Early stopping, best iteration is:
# [432]	valid_0's auc_mu: 0.985403	valid_0's multi_logloss: 0.281525
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.975943	valid_0's multi_logloss: 0.425337
# [200]	valid_0's auc_mu: 0.980951	valid_0's multi_logloss: 0.345332
# [300]	valid_0's auc_mu: 0.982869	valid_0's multi_logloss: 0.310666
# [400]	valid_0's auc_mu: 0.983976	valid_0's multi_logloss: 0.292367
# [500]	valid_0's auc_mu: 0.984672	valid_0's multi_logloss: 0.28329
# Early stopping, best iteration is:
# [516]	valid_0's auc_mu: 0.984846	valid_0's multi_logloss: 0.282434
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.975972	valid_0's multi_logloss: 0.424578
# [200]	valid_0's auc_mu: 0.980409	valid_0's multi_logloss: 0.345491
# [300]	valid_0's auc_mu: 0.982051	valid_0's multi_logloss: 0.316707
# [400]	valid_0's auc_mu: 0.98298	valid_0's multi_logloss: 0.302888
# [500]	valid_0's auc_mu: 0.983752	valid_0's multi_logloss: 0.293438
# Early stopping, best iteration is:
# [555]	valid_0's auc_mu: 0.983941	valid_0's multi_logloss: 0.290653
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.941945	valid_0's multi_logloss: 0.701548
# [200]	valid_0's auc_mu: 0.943577	valid_0's multi_logloss: 0.675754
# Early stopping, best iteration is:
# [230]	valid_0's auc_mu: 0.943653	valid_0's multi_logloss: 0.671655
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.943174	valid_0's multi_logloss: 0.684103
# Early stopping, best iteration is:
# [89]	valid_0's auc_mu: 0.943679	valid_0's multi_logloss: 0.690879
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.942446	valid_0's multi_logloss: 0.697534
# [200]	valid_0's auc_mu: 0.943648	valid_0's multi_logloss: 0.672716
# [300]	valid_0's auc_mu: 0.944171	valid_0's multi_logloss: 0.662717
# Early stopping, best iteration is:
# [352]	valid_0's auc_mu: 0.944392	valid_0's multi_logloss: 0.659681
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.973623	valid_0's multi_logloss: 0.497438
# [200]	valid_0's auc_mu: 0.97709	valid_0's multi_logloss: 0.438509
# [300]	valid_0's auc_mu: 0.978094	valid_0's multi_logloss: 0.414451
# [400]	valid_0's auc_mu: 0.978791	valid_0's multi_logloss: 0.401822
# [500]	valid_0's auc_mu: 0.979063	valid_0's multi_logloss: 0.397227
# [600]	valid_0's auc_mu: 0.979158	valid_0's multi_logloss: 0.394879
# [700]	valid_0's auc_mu: 0.979225	valid_0's multi_logloss: 0.393276
# Early stopping, best iteration is:
# [715]	valid_0's auc_mu: 0.979234	valid_0's multi_logloss: 0.393165
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.970534	valid_0's multi_logloss: 0.4975
# [200]	valid_0's auc_mu: 0.974952	valid_0's multi_logloss: 0.442735
# [300]	valid_0's auc_mu: 0.976481	valid_0's multi_logloss: 0.419425
# [400]	valid_0's auc_mu: 0.977182	valid_0's multi_logloss: 0.408005
# Early stopping, best iteration is:
# [454]	valid_0's auc_mu: 0.97748	valid_0's multi_logloss: 0.403791
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.97108	valid_0's multi_logloss: 0.503261
# [200]	valid_0's auc_mu: 0.974113	valid_0's multi_logloss: 0.447918
# [300]	valid_0's auc_mu: 0.975416	valid_0's multi_logloss: 0.423129
# [400]	valid_0's auc_mu: 0.976121	valid_0's multi_logloss: 0.413013
# [500]	valid_0's auc_mu: 0.976384	valid_0's multi_logloss: 0.409032
# Early stopping, best iteration is:
# [542]	valid_0's auc_mu: 0.976396	valid_0's multi_logloss: 0.408733
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58501
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc_mu: 0.5	valid_0's multi_logloss: 1.58555
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.983005	valid_0's multi_logloss: 0.345468
# [200]	valid_0's auc_mu: 0.984297	valid_0's multi_logloss: 0.31363
# [300]	valid_0's auc_mu: 0.984499	valid_0's multi_logloss: 0.307369
# Early stopping, best iteration is:
# [271]	valid_0's auc_mu: 0.984508	valid_0's multi_logloss: 0.307926
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.98181	valid_0's multi_logloss: 0.354685
# [200]	valid_0's auc_mu: 0.98334	valid_0's multi_logloss: 0.319444
# [300]	valid_0's auc_mu: 0.983576	valid_0's multi_logloss: 0.312314
# Early stopping, best iteration is:
# [356]	valid_0's auc_mu: 0.983628	valid_0's multi_logloss: 0.312062
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.980556	valid_0's multi_logloss: 0.359811
# [200]	valid_0's auc_mu: 0.981913	valid_0's multi_logloss: 0.32838
# Early stopping, best iteration is:
# [233]	valid_0's auc_mu: 0.9821	valid_0's multi_logloss: 0.325381
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.980629	valid_0's multi_logloss: 0.375072
# [200]	valid_0's auc_mu: 0.982576	valid_0's multi_logloss: 0.322603
# [300]	valid_0's auc_mu: 0.983866	valid_0's multi_logloss: 0.303065
# [400]	valid_0's auc_mu: 0.984678	valid_0's multi_logloss: 0.292373
# [500]	valid_0's auc_mu: 0.985182	valid_0's multi_logloss: 0.285867
# Early stopping, best iteration is:
# [555]	valid_0's auc_mu: 0.985277	valid_0's multi_logloss: 0.284005
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.979077	valid_0's multi_logloss: 0.390097
# [200]	valid_0's auc_mu: 0.982688	valid_0's multi_logloss: 0.328396
# [300]	valid_0's auc_mu: 0.983686	valid_0's multi_logloss: 0.306131
# [400]	valid_0's auc_mu: 0.9848	valid_0's multi_logloss: 0.292131
# [500]	valid_0's auc_mu: 0.985187	valid_0's multi_logloss: 0.285858
# [600]	valid_0's auc_mu: 0.985587	valid_0's multi_logloss: 0.280825
# Early stopping, best iteration is:
# [591]	valid_0's auc_mu: 0.985626	valid_0's multi_logloss: 0.280847
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.978992	valid_0's multi_logloss: 0.383343
# [200]	valid_0's auc_mu: 0.982172	valid_0's multi_logloss: 0.328451
# [300]	valid_0's auc_mu: 0.983052	valid_0's multi_logloss: 0.312288
# Early stopping, best iteration is:
# [353]	valid_0's auc_mu: 0.983312	valid_0's multi_logloss: 0.307682
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.979027	valid_0's multi_logloss: 0.399303
# [200]	valid_0's auc_mu: 0.98246	valid_0's multi_logloss: 0.3303
# [300]	valid_0's auc_mu: 0.984201	valid_0's multi_logloss: 0.298666
# Early stopping, best iteration is:
# [341]	valid_0's auc_mu: 0.984777	valid_0's multi_logloss: 0.290297
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.978564	valid_0's multi_logloss: 0.397463
# [200]	valid_0's auc_mu: 0.98254	valid_0's multi_logloss: 0.329625
# [300]	valid_0's auc_mu: 0.983493	valid_0's multi_logloss: 0.305776
# [400]	valid_0's auc_mu: 0.98445	valid_0's multi_logloss: 0.291873
# [500]	valid_0's auc_mu: 0.985172	valid_0's multi_logloss: 0.283348
# Early stopping, best iteration is:
# [503]	valid_0's auc_mu: 0.985196	valid_0's multi_logloss: 0.283275
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.976807	valid_0's multi_logloss: 0.408509
# [200]	valid_0's auc_mu: 0.981481	valid_0's multi_logloss: 0.334949
# [300]	valid_0's auc_mu: 0.983071	valid_0's multi_logloss: 0.306525
# [400]	valid_0's auc_mu: 0.983948	valid_0's multi_logloss: 0.292763
# [500]	valid_0's auc_mu: 0.984323	valid_0's multi_logloss: 0.289186
# Early stopping, best iteration is:
# [509]	valid_0's auc_mu: 0.984389	valid_0's multi_logloss: 0.288747
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.980467	valid_0's multi_logloss: 0.402909
# [200]	valid_0's auc_mu: 0.982745	valid_0's multi_logloss: 0.351435
# [300]	valid_0's auc_mu: 0.983347	valid_0's multi_logloss: 0.332716
# [400]	valid_0's auc_mu: 0.983687	valid_0's multi_logloss: 0.323335
# [500]	valid_0's auc_mu: 0.983784	valid_0's multi_logloss: 0.318678
# Early stopping, best iteration is:
# [544]	valid_0's auc_mu: 0.983822	valid_0's multi_logloss: 0.317822
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.978197	valid_0's multi_logloss: 0.413806
# [200]	valid_0's auc_mu: 0.98146	valid_0's multi_logloss: 0.35761
# [300]	valid_0's auc_mu: 0.982722	valid_0's multi_logloss: 0.334103
# [400]	valid_0's auc_mu: 0.983224	valid_0's multi_logloss: 0.32489
# [500]	valid_0's auc_mu: 0.983432	valid_0's multi_logloss: 0.320491
# Early stopping, best iteration is:
# [501]	valid_0's auc_mu: 0.983437	valid_0's multi_logloss: 0.320478
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.977556	valid_0's multi_logloss: 0.413769
# [200]	valid_0's auc_mu: 0.980827	valid_0's multi_logloss: 0.359507
# [300]	valid_0's auc_mu: 0.981388	valid_0's multi_logloss: 0.342496
# [400]	valid_0's auc_mu: 0.981651	valid_0's multi_logloss: 0.333602
# [500]	valid_0's auc_mu: 0.981871	valid_0's multi_logloss: 0.328928
# Early stopping, best iteration is:
# [479]	valid_0's auc_mu: 0.981874	valid_0's multi_logloss: 0.329247
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.99303	valid_0's multi_logloss: 0.195241
# Early stopping, best iteration is:
# [81]	valid_0's auc_mu: 0.99289	valid_0's multi_logloss: 0.192956
# Best score reached: 0.9245333333333333 with params: {'colsample_bytree': 0.952164731370897, 'min_child_samples': 111, 'min_child_weight': 0.01, 'num_leaves': 38, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.3029313662262354}

# %%
opt_parameters= {'colsample_bytree': 0.952164731370897, 'min_child_samples': 111, 'min_child_weight': 0.01, 'num_leaves': 38, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.3029313662262354}

# %%
#opt_parameters = {'colsample_bytree': 0.952164731370897, 'min_child_samples': 111, 'min_child_weight': 0.01, 'num_leaves': 38, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.3029313662262354}

# %%
#Configure from the HP optimisation
#clf_final = lgb.LGBMClassifier(**gs.best_estimator_.get_params())

#Configure locally from hardcoded values
clf_final = LGBMClassifier(**clf.get_params())
#set optimal parameters
clf_final.set_params(**opt_parameters)

#Train the final model with learning rate decay
clf_final.fit(X_train, y_train, **fit_params, callbacks=[lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_0995)])
# Out:
# Training until validation scores don't improve for 30 rounds
# [100]	valid_0's auc_mu: 0.99333	valid_0's multi_logloss: 0.186248
# Early stopping, best iteration is:
# [125]	valid_0's auc_mu: 0.993517	valid_0's multi_logloss: 0.185107
# LGBMClassifier(colsample_bytree=0.952164731370897, min_child_samples=111,
#                min_child_weight=0.01, n_estimators=5000, num_leaves=38,
#                random_state=42, reg_alpha=0, reg_lambda=0.1,
#                subsample=0.3029313662262354)

# %%
feat_imp = pd.Series(clf_final.feature_importances_, index=x.columns)
feat_imp.nlargest(20).plot(kind='barh', figsize=(8,10))
# Out:
# <AxesSubplot: >

# %%
probabilities = clf_final.predict(X_test)

report = classification_report(y_test, probabilities)
print(report)
accuracy = accuracy_score(y_test, probabilities)
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       517
#            1       0.86      0.92      0.88       189
#            2       0.85      0.77      0.81       144
#            3       0.90      0.89      0.90       265
#            4       0.89      0.92      0.91       135
#
#     accuracy                           0.92      1250
#    macro avg       0.90      0.90      0.90      1250
# weighted avg       0.92      0.92      0.92      1250
#
# 0.9248
